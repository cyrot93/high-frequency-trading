# %% [markdown]
# <b> import statements

# %%
import sys

import numpy as np
import pandas as pd
import datetime
import time


import requests
import re
from bs4 import BeautifulSoup
from time import sleep
import pickle

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

sns.set_style("whitegrid", {'axes.grid' : False})

# %%
from sklearn import cross_validation, datasets, linear_model, grid_search, metrics, ensemble, tree
from sklearn import pipeline, manifold, preprocessing, feature_selection, decomposition
from sklearn.preprocessing import PolynomialFeatures, StandardScaler, MinMaxScaler
from sklearn.learning_curve import learning_curve
from sklearn.cross_validation import cross_val_score

# Classifiers
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier
# Out:
# /Users/Cyril/anaconda/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /Users/Cyril/anaconda/lib/python3.6/site-packages/sklearn/grid_search.py:43: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)
# /Users/Cyril/anaconda/lib/python3.6/site-packages/sklearn/learning_curve.py:23: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the functions are moved. This module will be removed in 0.20
#   DeprecationWarning)

# %%
from pandas import Series, DataFrame, Panel
import scipy; 
import scipy.stats as stats; 
from scipy.stats import ttest_ind, ttest_ind_from_stats; from scipy.special import stdtr;

# %% [markdown]
# <b> defining lobster

# %%
from pandas import DataFrame, read_csv, concat
from os import path
import numpy as np
from datetime import timedelta
from enum import Enum

class OrderEvent(Enum):
    SUBMISSION = 1
    CANCELLATION = 2
    DELETION = 3
    EXECUTION = 4
    HIDDEN_EXECUTION =5
    CROSS_TRADE = 6
    TRADING_HALT  = 7
    OTHER = 8

__EventMap = {}

for e in OrderEvent:
    __EventMap[e.value] = e

def get_orderEvent(eventid):
    return __EventMap[eventid]


class LobsterData:
    def __init__(self):
        self.order_books = None
        self.messages = DataFrame()
        self.level = 0

    def read_single_day_data(self, order_book_file, message_file, append=True, convert_time=False):
        file_name = path.basename(order_book_file)
        file_base = path.splitext(file_name)[0]
        mydate = np.datetime64('{0}T00:00-0000'.format(file_base.split('_')[1]))

        myorderbooks = read_csv(order_book_file, header=None)
        mymessages = read_csv(message_file, header=None)
        columns = []
        for iCol in range(int(len(myorderbooks.columns) / 4 + 0.5)):
            columns.append('Ask_Price_{0}'.format(iCol + 1))
            columns.append('Ask_Size_{0}'.format(iCol + 1))
            columns.append('Bid_Price_{0}'.format(iCol + 1))
            columns.append('Bid_Size_{0}'.format(iCol + 1))
        myorderbooks.columns = columns
        mymessages.columns = ['Time', 'Event', 'Order_ID', 'Size', 'Price', 'Direction']
        mymessages.Event = mymessages['Event'].map(get_orderEvent)
        mymessages['Date'] = mydate
        if convert_time:
            mymessages.Time = mymessages.Time.apply(lambda x: mydate + np.timedelta64(int(x * 1e9), 'ns'))

        mymessages.set_index(['Date', 'Time'], inplace=True)
        myorderbooks.index = mymessages.index

        if append:
            self.order_books = concat([self.order_books, myorderbooks], axis=0)
            self.messages = concat([self.messages, mymessages], axis=0)
        else:
            self.order_books = myorderbooks
            self.messages = mymessages
        self.level = int(self.order_books.shape[1] / 4 + 0.5)

    def read_period_data(self, ticker, level, start_date, end_date, data_path='./', **kwargs):
        my_date = start_date
        while my_date <= end_date:
            print('read {0}'.format(my_date.strftime('%Y-%m-%d')))
            order_book_file = "{0}/{1}_{2}_34200000_57600000_orderbook_{3}.csv".format(data_path, ticker,
                                                                                       my_date.strftime('%Y-%m-%d'),
                                                                                       level)

            message_file = "{0}/{1}_{2}_34200000_57600000_message_{3}.csv".format(data_path, ticker,
                                                                                       my_date.strftime('%Y-%m-%d'),
                                                                                       level)
            self.read_single_day_data(order_book_file, message_file, **kwargs)
            my_date += timedelta(1)

    def get_number_of_record(self):
        return self.order_books.shape[0]

    def get_number_of_level(self):
        return self.level

    def get_trades(self, combined=True, combination_interval=100):
        pass
    
    def exclude_trade_halt_data(self):
        halt_indicators = where(self.message.event == 7)
        
    def plot_orderbook(self):
        pass

# %% [markdown]
# Output Structure:
# ---------------
#
# LOBSTER generates a 'message' and an 'orderbook' file for each active
# trading day of a selected ticker. The 'orderbook' file contains the
# evolution of the limit order book up to the requested number of levels.
# The 'message' file contains indicators for the type of event causing
# an update of the limit order book in the requested price range. All
# events are timestamped to seconds after midnight, with decimal
# precision of at least milliseconds and up to nanoseconds depending
# on the requested period.
#
#
# 	Message File:		(Matrix of size: (Nx6))
# 	-------------
#
# 	Name: 	TICKER_Year-Month-Day_StartTime_EndTime_message_LEVEL.csv
#
# 		StartTime and EndTime give the theoretical beginning
# 		and end time of the output file in milliseconds after
# 		mid night. LEVEL refers to the number of levels of the
# 		requested limit order book.
#
#
# 	Columns:
#
# 	    1.) Time:
# 				Seconds after midnight with decimal
# 				precision of at least milliseconds
# 				and up to nanoseconds depending on
# 				the requested period
# 	    2.) Type:
# 				1: Submission of a new limit order
# 				2: Cancellation (Partial deletion
# 				   of a limit order)
# 				3: Deletion (Total deletion of a limit order)
# 				4: Execution of a visible limit order
# 				5: Execution of a hidden limit order
# 				7: Trading halt indicator
# 				   (Detailed information below)
# 	    3.) Order ID:
# 				Unique order reference number
# 				(Assigned in order flow)
# 	    4.) Size:
# 				Number of shares
# 	    5.) Price:
# 				Dollar price times 10000
# 				(i.e., A stock price of $91.14 is given
# 				by 911400)
# 	    6.) Direction:
# 				-1: Sell limit order
# 				1: Buy limit order
#
# 				Note:
# 				Execution of a sell (buy) limit
# 				order corresponds to a buyer (seller)
# 				initiated trade, i.e. Buy (Sell) trade.
#
#
# 	Orderbook File:		(Matrix of size: (Nx(4xNumberOfLevels)))
# 	---------------
#
# 	Name: 	TICKER_Year-Month-Day_StartTime_EndTime_orderbook_LEVEL.csv
#
# 	Columns:
#
#  	    1.) Ask Price 1: 	Level 1 Ask Price 	(Best Ask)
# 	    2.) Ask Size 1: 	Level 1 Ask Volume 	(Best Ask Volume)
# 	    3.) Bid Price 1: 	Level 1 Bid Price 	(Best Bid)
# 	    4.) Bid Size 1: 	Level 1 Bid Volume 	(Best Bid Volume)
# 	    5.) Ask Price 2: 	Level 2 Ask Price 	(2nd Best Ask)
# 	    ...
#
# 	Notes:
# 	------
#
# 		- Levels:
#
# 		The term level refers to occupied price levels. This implies
# 		that the difference between two levels in the LOBSTER output
# 		is not necessarily the minimum ticks size.
#
# 		- Unoccupied Price Levels:
#
# 		When the selected number of levels exceeds the number of levels
# 		available the empty order book positions are filled with dummy
# 		information to guarantee a symmetric output. The extra bid
# 		and/or ask prices are set to -9999999999 and 9999999999,
# 		respectively. The Corresponding volumes are set to 0.
#
# 		- Trading Halts:
#
# 		When trading halts, a message of type '7' is written into the
# 		'message' file. The corresponding price and trade direction
# 		are set to '-1' and all other properties are set to '0'.
# 		Should the resume of quoting be indicated by an additional
# 		message in NASDAQ's Historical TotalView-ITCH files, another
# 		message of type '7' with price '0' is added to the 'message'
# 		file. Again, the trade direction is set to '-1' and all other
# 		fields are set to '0'.
# 		When trading resumes a message of type '7' and
# 		price '1' (Trade direction '-1' and all other
# 		entries '0') is written to the 'message' file. For messages
# 		of type '7', the corresponding order book rows contain a
# 		duplication of the preceding order book state. The reason
# 		for the trading halt is not included in the output.
#
# 			Example: Stylized trading halt messages in 'message' file.
#
# 			Halt: 				36023	| 7 | 0 | 0 | -1 | -1
# 											...
# 			Quoting: 			36323 	| 7 | 0 | 0 | 0  | -1
# 											...
# 			Resume Trading:		36723   | 7 | 0 | 0 | 1  | -1
# 											...
#
# 			The vertical bars indicate the different columns in the
# 			message file.
#
# =========================================================================

# %%
d = LobsterData()

# %%
d.read_single_day_data('AMZN_2012-06-21_34200000_57600000_orderbook_5.csv', 'AMZN_2012-06-21_34200000_57600000_message_5.csv', append=True, convert_time=False)
# Out:
# /Users/Cyril/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:35: DeprecationWarning: parsing timezone aware datetimes is deprecated; this will raise an error in the future

# %%
print(d.get_number_of_record())
# Out:
# 155935

# %%
print(d.get_number_of_level())
# Out:
# 5

# %%
ob = read_csv('AMZN_2012-06-21_34200000_57600000_orderbook_5.csv', header=None)
mb = read_csv('AMZN_2012-06-21_34200000_57600000_message_5.csv', header=None)

# %% [markdown]
# <b> PART 0 - GET THE RELEVANT STRUCTURES <br/>
# 1- the 5-level limit order book --> used to get the S's <br/>
# 2- the buy/sell limit orders placed --> used to get the L's <br/>
# 3- the buy/sell market orders executed --> used to get the M's <br/>
# 4- the buy/sell cancelled orders --> used to get the C's

# %%
# 1- the 5-level limit order book
lob = d.order_books
Time = []
Date = []
for idx,row in lob.iterrows():
    Time.append(idx[1])
lob['Time'] = Time
lob.tail()
# Out:
#                          Ask_Price_1  Ask_Size_1  Bid_Price_1  Bid_Size_1  \
# Date       Time
# 2012-06-21 57599.545828      2206200         100      2205100         249
#            57599.903989      2206400         100      2205100         249
#            57599.955242      2206400         100      2205100         249
#            57599.958245      2206300         100      2205100         249
#            57599.959360      2206400         100      2205100         249
#
#                          Ask_Price_2  Ask_Size_2  Bid_Price_2  Bid_Size_2  \
# Date       Time
# 2012-06-21 57599.545828      2206400         100      2205000          71
#            57599.903989      2206500        1290      2205000          71
#            57599.955242      2206500        1290      2205000          71
#            57599.958245      2206400         100      2205000          71
#            57599.959360      2206500        1290      2205000          71
#
#                          Ask_Price_3  Ask_Size_3      ...       Bid_Size_3  \
# Date       Time                                       ...
# 2012-06-21 57599.545828      2206500        1290      ...              700
#            57599.903989      2206700         170      ...              700
#            57599.955242      2206700         170      ...              700
#            57599.958245      2206500        1290      ...              700
#            57599.959360      2206700         170      ...              700
#
#                          Ask_Price_4  Ask_Size_4  Bid_Price_4  Bid_Size_4  \
# Date       Time
# 2012-06-21 57599.545828      2206700         170      2204700         100
#            57599.903989      2206900         170      2204700         100
#            57599.955242      2207100        1800      2204700         100
#            57599.958245      2206700         170      2204700         100
#            57599.959360      2207100        1800      2204700         100
#
#                          Ask_Price_5  Ask_Size_5  Bid_Price_5  Bid_Size_5  \
# Date       Time
# 2012-06-21 57599.545828      2206900         170      2204600        1704
#            57599.903989      2207100        1800      2204600        1704
#            57599.955242      2207400         800      2204600        1704
#            57599.958245      2207100        1800      2204600        1704
#            57599.959360      2207400         800      2204600        1704
#
#                                  Time
# Date       Time
# 2012-06-21 57599.545828  57599.545828
#            57599.903989  57599.903989
#            57599.955242  57599.955242
#            57599.958245  57599.958245
#            57599.959360  57599.959360
#
# [5 rows x 21 columns]

# %%
# 2- the buy/sell limit orders placed --> used to get the L's 
limit_b = mb[(mb[1] == 1) & (mb[5] == 1)]
print(limit_b.tail())
print()
limit_s = mb[(mb[1] == 1) & (mb[5] == -1)]
print(limit_s.tail())
# Out:
#                    0  1          2    3        4  5
# 155886  57598.107097  1  287075582  100  2205600  1
# 155892  57598.316250  1  287087236  100  2205700  1
# 155897  57598.359060  1  287089309  100  2205400  1
# 155911  57599.103251  1  287126323  100  2204800  1
# 155924  57599.403081  1  287148338  100  2204800  1
#
#                    0  1          2    3        4  5
# 155916  57599.241943  1  287140757  100  2206100 -1
# 155920  57599.282618  1  287142670   25  2206500 -1
# 155921  57599.285831  1  287142900  100  2206200 -1
# 155926  57599.503155  1  287154282  170  2206700 -1
# 155933  57599.958245  1  287174077  100  2206300 -1

# %%
# 3- the buy/sell market orders executed --> used to get the M's 
market_b = mb[((mb[1] == 4) | (mb[1] == 5)) & (mb[5] == 1)]
print(market_b.tail())
print()
market_s = mb[((mb[1] == 4) | (mb[1] == 5)) & (mb[5] == -1)]
print(market_s.tail())
# Out:
#                    0  1          2    3        4  5
# 155907  57599.061375  4  286888769  100  2205300  1
# 155914  57599.241762  4  286932759  100  2205200  1
# 155923  57599.402707  4  282917222   91  2205100  1
# 155929  57599.545828  4  282917222    9  2205100  1
# 155930  57599.545828  4  286916542   51  2205100  1
#
#                    0  1          2    3        4  5
# 155884  57598.103362  4  287061322  100  2206300 -1
# 155889  57598.212719  5          0  139  2206300 -1
# 155890  57598.234339  5          0  100  2206300 -1
# 155900  57598.401009  5          0   47  2206300 -1
# 155917  57599.242004  4  287140745    9  2205300 -1

# %%
# 4- the buy/sell cancelled orders --> used to get the C's
cancelled_b = mb[((mb[1] == 2) | (mb[1] == 3)) & (mb[5] == 1)]
print(cancelled_b.tail())
print()
cancelled_s = mb[((mb[1] == 2) | (mb[1] == 3)) & (mb[5] == -1)]
print(cancelled_s.tail())
# Out:
#                    0  1          2    3        4  5
# 155904  57599.030778  3  287089309  100  2205400  1
# 155906  57599.031347  3  286826912  100  2205100  1
# 155910  57599.103031  3  287074627  100  2204900  1
# 155918  57599.280717  3  287126323  100  2204800  1
# 155927  57599.537680  3  286844366  100  2204700  1
#
#                    0  1          2    3        4  5
# 155925  57599.502960  3  287140757  100  2206100 -1
# 155928  57599.545699  3  287094952   60  2206400 -1
# 155931  57599.903989  3  287142900  100  2206200 -1
# 155932  57599.955242  3  286967592  170  2206900 -1
# 155934  57599.959360  3  287174077  100  2206300 -1

# %% [markdown]
# <b> PART 1 - the generic function to return the feature and label vectors

# %%
# this function will return the feature and label vectors.
# in order to determine the linear price impact coefficient c
# it takes as input:
#    - the limit order book lob (previously built)
#    - the buy/sell limit orders limit_{b/s} (previously built)
#    - the buy/sell cancelled orders cancelled_{b/s} (previously built)
#    - the buy/sell market orders market_{b/s} (previously built)
#    - the desired time period D (in seconds)
# it returns as output:
#    - the samples S_X, S_y of all (y = price changes) and (X = OFI's) from start to end for 30 min
#    - the average depth (AVD) from start to end for 30 min
def get_features_labels(lob, limit_b, limit_s, cancelled_b, cancelled_s, market_b, market_s, D):
    S_X = []
    S_y = []
    AVD = []
    start = lob['Time'].iloc[0]
    end = lob['Time'].iloc[-1]
    sample = 0
    while(start < end):
        
        X = []
        y = []

        cur_end = start + 1800
        
        # get the average depth during this period
        AD = 0
        lob_cur = lob[(lob['Time'] >= start) & (lob['Time'] <= cur_end)]
        for i in range(5):
            AD = AD + lob_cur['Ask_Size_'+str(i+1)].mean()
            AD = AD + lob_cur['Bid_Size_'+str(i+1)].mean()
        AD = AD / 10
        
        # get the other samples during this period
        while(start<cur_end):
        
            # a- get the corresponding OFI(t,t+D)/D(t)
            # how? we just count the parameters L,C,M
            # and we "estimate" the average depth of a level i.e. number of shares by level in the lob

            # here we compute the parameters L,C,M
            # L:
            limit_cur_1 = limit_b[(limit_b[0] >= start) & (limit_b[0] <= start + D)] 
            limit_cur_2 = limit_s[(limit_s[0] >= start) & (limit_s[0] <= start + D)] 
            L_b = 0 # number of buy limit orders
            L_s = 0 # number of sell limit orders
            for idx,row in limit_cur_1.iterrows():
                L_b = L_b + row[3]
            for idx,row in limit_cur_2.iterrows():
                L_s = L_s + row[3]
            # C:
            cancelled_cur_1 = cancelled_b[(cancelled_b[0] >= start) & (cancelled_b[0] <= start + D)]
            cancelled_cur_2 = cancelled_s[(cancelled_s[0] >= start) & (cancelled_s[0] <= start + D)]
            C_b = 0 # number of buy cancelled orders
            C_s = 0 # number of sell cancelled orders
            for idx,row in cancelled_cur_1.iterrows():
                C_b = C_b + row[3]
            for idx,row in cancelled_cur_2.iterrows():
                C_s = C_s + row[3]
            # M:
            market_cur_1 = market_b[(market_b[0] >= start) & (market_b[0] <= start + D)]
            market_cur_2 = market_s[(market_s[0] >= start) & (market_s[0] <= start + D)]
            M_b = 0 # number of buy market orders
            M_s = 0 # number of sell market orders
            for idx,row in market_cur_1.iterrows():
                M_b = M_b + row[3]
            for idx,row in market_cur_2.iterrows():
                M_s = M_s + row[3]
            # here we check that the lob is non-empty during the time period
            lob1 = lob[(lob['Time'] >= start) & (lob['Time'] <= start + 1)]
            lob2 = lob[(lob['Time'] >= start + D) & (lob['Time'] <= start + D + 1)]
            if(lob1.size < 2 or lob2.size < 2):
                start = start + D
                continue


            # b- get the corresponding label (S(t+D)-S(t))/d
            Delta_S = (0.5*(lob2['Ask_Price_1'].iloc[0] + lob2['Bid_Price_1'].iloc[0])\
                     -0.5*(lob1['Ask_Price_1'].iloc[0] + lob1['Bid_Price_1'].iloc[0]))/100
            
            # here we filter some bad examples
            OFI = 0.5*(L_b-C_b-M_b) - 0.5*(L_s-C_s-M_s)
            if(Delta_S < min(-0.01*OFI,0.01*OFI) or Delta_S > max(-0.01*OFI,0.01*OFI) or OFI < -1500 or OFI > 1500):
                start = start + D
                continue
            
            # here we append our examples to our feature vector
            X.append(OFI)
            y.append(Delta_S)

            # next time period
            start = start + D

        X = np.array(X)
        X = X.reshape((X.shape[0],1))
        y = np.array(y)
        y = y.reshape((y.shape[0],1))
        
        if(X.size>0 and y.size>0):
            S_X.append(X)
            S_y.append(y)
            AVD.append(AD)
            
        # next sample
        print('Done with adding sample ',sample,' with size ',X.size,' = ',y.size)
        sample = sample+1
        start = cur_end
        
    S_X = np.array(S_X)
    S_y = np.array(S_y)
    AVD = np.array(AVD)
    
    return S_X, S_y, AVD

# %%
# get all the samples, D=1sec
S_X, S_y, AVD = get_features_labels(lob, limit_b, limit_s, cancelled_b, cancelled_s, market_b, market_s, 1)
print('we have a total of samples = ',S_X.shape[0])
# Out:
# Done with adding sample  0  with size  597  =  597
# Done with adding sample  1  with size  705  =  705
# Done with adding sample  2  with size  730  =  730
# Done with adding sample  3  with size  710  =  710
# Done with adding sample  4  with size  621  =  621
# Done with adding sample  5  with size  571  =  571
# Done with adding sample  6  with size  515  =  515
# Done with adding sample  7  with size  519  =  519
# Done with adding sample  8  with size  628  =  628
# Done with adding sample  9  with size  635  =  635
# Done with adding sample  10  with size  484  =  484
# Done with adding sample  11  with size  702  =  702
# Done with adding sample  12  with size  890  =  890
# we have a total of samples =  13

# %%
# get all the samples, D=10sec
S_X_10, S_y_10, AVD_10 = get_features_labels(lob, limit_b, limit_s, cancelled_b, cancelled_s, market_b, market_s, 10)
print('we have a total of samples = ',S_X_10.shape[0])
# Out:
# Done with adding sample  0  with size  21  =  21
# Done with adding sample  1  with size  30  =  30
# Done with adding sample  2  with size  44  =  44
# Done with adding sample  3  with size  43  =  43
# Done with adding sample  4  with size  33  =  33
# Done with adding sample  5  with size  43  =  43
# Done with adding sample  6  with size  42  =  42
# Done with adding sample  7  with size  42  =  42
# Done with adding sample  8  with size  54  =  54
# Done with adding sample  9  with size  41  =  41
# Done with adding sample  10  with size  31  =  31
# Done with adding sample  11  with size  43  =  43
# Done with adding sample  12  with size  77  =  77
# we have a total of samples =  13

# %% [markdown]
# <b> PART 2 - OLS function

# %%
# this function performs OLS on X,y.
# takes also as a parameter D (time diff), and to_plot (if we desire plots on the OLS)
def OLS(X,y,D,to_plot):
    
    # 1- OLS
    from sklearn import datasets, linear_model
    from sklearn.metrics import mean_squared_error, r2_score
    from sklearn.model_selection import KFold
    
    coefs = []
    rmses = []
    r2s = []
    rmses_train = []
    r2s_train = []
    kf = KFold(n_splits=4, random_state=None, shuffle=True)
    kf.get_n_splits(X)
    for train_index, test_index in kf.split(X):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        regr = linear_model.LinearRegression()
        regr.fit(X_train, y_train)
        y_pred = regr.predict(X_test)
        coefs.append(regr.coef_)
        rmses.append(mean_squared_error(y_test, y_pred))
        r2s.append(r2_score(y_test, y_pred))
        y_pred_2 = regr.predict(X_train)
        rmses_train.append(mean_squared_error(y_train, y_pred_2))
        r2s_train.append(r2_score(y_train, y_pred_2))
    coefs = np.array(coefs)
    rmses = np.array(rmses)
    r2s = np.array(r2s)
    rmses_train = np.array(rmses_train)
    r2s_train = np.array(r2s_train)
        
    print('Coefficients: \n', np.mean(coefs))
    print("Mean squared error: %.2f"
              % np.mean(rmses))
    print('r^2: %.2f' % np.mean(r2s))
    print("(training) Mean squared error: %.2f"
              % np.mean(rmses_train))
    print('(training) r^2: %.2f' % np.mean(r2s_train))
    
    if(to_plot == 1):
        # 2- qq-plot of y_test - y_pred against normal distribution
        import pylab 
        import scipy.stats as stats
        measurements = y_test[:,0] - y_pred[:,0]
        stats.probplot(measurements, dist="norm", plot=pylab)
        pylab.title('OLS - qq-plot against normal (' + str(D) + ' sec)')
        pylab.show()

        # 3- qq-plot of y_test - y_pred against uniform distribution
        measurements = y_test[:,0] - y_pred[:,0]
        stats.probplot(measurements, dist="uniform", plot=pylab)
        pylab.title('OLS - qq-plot against uniform(' + str(D) + ' sec)')
        pylab.show()

        # 4- post-OLS plot
        s = [5 for n in range(len(X))]
        title = 'OLS - order flow imbalance VS price change (' + str(D) + ' sec)'
        plt.figure()
        plt.scatter(X,y,s=s)
        lines = plt.plot(X_test, y_pred)
        plt.setp(lines, 'color', 'r', 'linewidth', 1.0)
        plt.xlabel(r'$OFI(t,t+\Delta)$', fontsize=10)
        plt.ylabel(r'$\frac{S(t+\Delta)-S(t)}{\delta}$', fontsize=10)
        plt.axhline(0, linewidth = 0.5, color='grey')
        plt.axvline(0, linewidth = 0.5, color='grey')
        plt.xlim((-500,500))
        plt.ylim((-4,4))
        
        plt.title(title)
        plt.show()
        
    return np.mean(coefs),np.mean(rmses),np.mean(r2s), np.mean(rmses_train),np.mean(r2s_train)

# %% [markdown]
# <b> PART 3 - OLS on ALL the samples

# %%
# here we get the average OLS info accross all the samples - D = 1 sec
sample = 0
betas = []
rmses = []
r2s = []
rmses_train = []
r2s_train = []
while(sample < len(S_X)):
    print('sample #',sample)
    beta,rmse,r2, rmse_train, r2_train = OLS(S_X[sample],S_y[sample],1,0)
    print()
    betas.append(beta)
    rmses.append(rmse)
    r2s.append(r2)
    rmses_train.append(rmse_train)
    r2s_train.append(r2_train)
    sample = sample + 1
betas = np.array(betas)
rmses = np.array(rmses)
r2s = np.array(r2s)
cs = betas*73
print('Average regression coefficient: beta_avg = ',np.mean(betas))
print('min regression coefficient: beta_min = ',np.min(betas))
print('max regression coefficient: beta_max = ',np.max(betas))
print('Average depth-adjusted regression coefficient: c_avg',np.mean(cs))
print('min depth-adjusted regression coefficient: c_min',np.min(cs))
print('max depth-adjusted regression coefficient: c_max',np.max(cs))
print('Average RMSE: RMSE_avg = ',np.mean(rmses))
print('min RMSE: RMSE_min = ',np.min(rmses))
print('max RMSE: RMSE_max = ',np.max(rmses))
print('Average r^2: r2_avg = ',np.mean(r2s))
print('min r^2: r2_min = ',np.min(r2s))
print('max r^2: r2_max = ',np.max(r2s))
print('(train) Average RMSE: RMSE_avg = ',np.mean(rmses_train))
print('(train) min RMSE: RMSE_min = ',np.min(rmses_train))
print('(train) max RMSE: RMSE_max = ',np.max(rmses_train))
print('(train) Average r^2: r2_avg = ',np.mean(r2s_train))
print('(train) min r^2: r2_min = ',np.min(r2s_train))
print('(train) max r^2: r2_max = ',np.max(r2s_train))
# Out:
# sample # 0
# Coefficients:
#  0.00321263794163
# Mean squared error: 0.38
# r^2: 0.28
# (training) Mean squared error: 0.34
# (training) r^2: 0.39
#
# sample # 1
# Coefficients:
#  0.00356312196761
# Mean squared error: 0.41
# r^2: 0.42
# (training) Mean squared error: 0.39
# (training) r^2: 0.51
#
# sample # 2
# Coefficients:
#  0.00394516970217
# Mean squared error: 0.73
# r^2: 0.50
# (training) Mean squared error: 0.71
# (training) r^2: 0.54
#
# sample # 3
# Coefficients:
#  0.00510825090436
# Mean squared error: 0.61
# r^2: 0.62
# (training) Mean squared error: 0.58
# (training) r^2: 0.66
#
# sample # 4
# Coefficients:
#  0.00391022103188
# Mean squared error: 0.37
# r^2: 0.49
# (training) Mean squared error: 0.36
# (training) r^2: 0.52
#
# sample # 5
# Coefficients:
#  0.00506394728585
# Mean squared error: 0.52
# r^2: 0.64
# (training) Mean squared error: 0.51
# (training) r^2: 0.66
#
# sample # 6
# Coefficients:
#  0.00502237762147
# Mean squared error: 0.54
# r^2: 0.51
# (training) Mean squared error: 0.51
# (training) r^2: 0.61
#
# sample # 7
# Coefficients:
#  0.00394506856173
# Mean squared error: 0.41
# r^2: 0.47
# (training) Mean squared error: 0.36
# (training) r^2: 0.59
#
# sample # 8
# Coefficients:
#  0.00412133113451
# Mean squared error: 0.67
# r^2: 0.53
# (training) Mean squared error: 0.62
# (training) r^2: 0.58
#
# sample # 9
# Coefficients:
#  0.00476703341622
# Mean squared error: 0.74
# r^2: 0.43
# (training) Mean squared error: 0.62
# (training) r^2: 0.67
#
# sample # 10
# Coefficients:
#  0.00393310007658
# Mean squared error: 0.50
# r^2: 0.56
# (training) Mean squared error: 0.48
# (training) r^2: 0.58
#
# sample # 11
# Coefficients:
#  0.00511765928743
# Mean squared error: 0.71
# r^2: 0.65
# (training) Mean squared error: 0.67
# (training) r^2: 0.68
#
# sample # 12
# Coefficients:
#  0.00371004235924
# Mean squared error: 1.13
# r^2: 0.52
# (training) Mean squared error: 1.11
# (training) r^2: 0.53
#
# Average regression coefficient: beta_avg =  0.00426307394544
# min regression coefficient: beta_min =  0.00321263794163
# max regression coefficient: beta_max =  0.00511765928743
# Average depth-adjusted regression coefficient: c_avg 0.311204398017
# min depth-adjusted regression coefficient: c_min 0.234522569739
# max depth-adjusted regression coefficient: c_max 0.373589127983
# Average RMSE: RMSE_avg =  0.594099333918
# min RMSE: RMSE_min =  0.372151518558
# max RMSE: RMSE_max =  1.13309146787
# Average r^2: r2_avg =  0.509357869832
# min r^2: r2_min =  0.279772884709
# max r^2: r2_max =  0.646895103807
# (train) Average RMSE: RMSE_avg =  0.559098633957
# (train) min RMSE: RMSE_min =  0.343123914891
# (train) max RMSE: RMSE_max =  1.10796913502
# (train) Average r^2: r2_avg =  0.578271411978
# (train) min r^2: r2_min =  0.385086227596
# (train) max r^2: r2_max =  0.683645771458

# %%
# here we get the average OLS info accross all the samples - D = 1 sec
sample = 0
betas = []
rmses = []
r2s = []
rmses_train = []
r2s_train = []
while(sample < len(S_X_10)):
    print('sample #',sample)
    beta,rmse,r2, rmse_train, r2_train = OLS(S_X_10[sample],S_y_10[sample],10,0)
    print()
    betas.append(beta)
    rmses.append(rmse)
    r2s.append(r2)
    rmses_train.append(rmse_train)
    r2s_train.append(r2_train)
    sample = sample + 1
betas = np.array(betas)
rmses = np.array(rmses)
r2s = np.array(r2s)
cs = betas*73
print('Average regression coefficient: beta_avg = ',np.mean(betas))
print('min regression coefficient: beta_min = ',np.min(betas))
print('max regression coefficient: beta_max = ',np.max(betas))
print('Average depth-adjusted regression coefficient: c_avg',np.mean(cs))
print('min depth-adjusted regression coefficient: c_min',np.min(cs))
print('max depth-adjusted regression coefficient: c_max',np.max(cs))
print('Average RMSE: RMSE_avg = ',np.mean(rmses))
print('min RMSE: RMSE_min = ',np.min(rmses))
print('max RMSE: RMSE_max = ',np.max(rmses))
print('Average r^2: r2_avg = ',np.mean(r2s))
print('min r^2: r2_min = ',np.min(r2s))
print('max r^2: r2_max = ',np.max(r2s))
print('(train) Average RMSE: RMSE_avg = ',np.mean(rmses_train))
print('(train) min RMSE: RMSE_min = ',np.min(rmses_train))
print('(train) max RMSE: RMSE_max = ',np.max(rmses_train))
print('(train) Average r^2: r2_avg = ',np.mean(r2s_train))
print('(train) min r^2: r2_min = ',np.min(r2s_train))
print('(train) max r^2: r2_max = ',np.max(r2s_train))
# Out:
# sample # 0
# Coefficients:
#  0.00583350448825
# Mean squared error: 2.17
# r^2: -4.51
# (training) Mean squared error: 1.34
# (training) r^2: 0.82
#
# sample # 1
# Coefficients:
#  0.00601602426666
# Mean squared error: 5.39
# r^2: -0.38
# (training) Mean squared error: 4.03
# (training) r^2: 0.65
#
# sample # 2
# Coefficients:
#  0.00508691364623
# Mean squared error: 4.65
# r^2: 0.49
# (training) Mean squared error: 3.57
# (training) r^2: 0.74
#
# sample # 3
# Coefficients:
#  0.00439665137033
# Mean squared error: 4.72
# r^2: 0.09
# (training) Mean squared error: 3.39
# (training) r^2: 0.57
#
# sample # 4
# Coefficients:
#  0.00474867856374
# Mean squared error: 3.26
# r^2: 0.61
# (training) Mean squared error: 2.78
# (training) r^2: 0.68
#
# sample # 5
# Coefficients:
#  0.00641106699994
# Mean squared error: 3.06
# r^2: 0.79
# (training) Mean squared error: 2.62
# (training) r^2: 0.85
#
# sample # 6
# Coefficients:
#  0.00574534630202
# Mean squared error: 3.24
# r^2: 0.62
# (training) Mean squared error: 2.75
# (training) r^2: 0.75
#
# sample # 7
# Coefficients:
#  0.00485162293081
# Mean squared error: 1.79
# r^2: 0.62
# (training) Mean squared error: 1.12
# (training) r^2: 0.83
#
# sample # 8
# Coefficients:
#  0.00562767122654
# Mean squared error: 4.62
# r^2: 0.68
# (training) Mean squared error: 4.41
# (training) r^2: 0.75
#
# sample # 9
# Coefficients:
#  0.00700375193217
# Mean squared error: 3.17
# r^2: 0.83
# (training) Mean squared error: 2.99
# (training) r^2: 0.85
#
# sample # 10
# Coefficients:
#  0.00574640319937
# Mean squared error: 2.86
# r^2: 0.74
# (training) Mean squared error: 2.07
# (training) r^2: 0.84
#
# sample # 11
# Coefficients:
#  0.00642360143065
# Mean squared error: 4.54
# r^2: 0.76
# (training) Mean squared error: 3.88
# (training) r^2: 0.85
#
# sample # 12
# Coefficients:
#  0.00518470853786
# Mean squared error: 5.05
# r^2: 0.73
# (training) Mean squared error: 4.86
# (training) r^2: 0.78
#
# Average regression coefficient: beta_avg =  0.00562122653035
# min regression coefficient: beta_min =  0.00439665137033
# max regression coefficient: beta_max =  0.00700375193217
# Average depth-adjusted regression coefficient: c_avg 0.410349536716
# min depth-adjusted regression coefficient: c_min 0.320955550034
# max depth-adjusted regression coefficient: c_max 0.511273891048
# Average RMSE: RMSE_avg =  3.73218202466
# min RMSE: RMSE_min =  1.79229896032
# max RMSE: RMSE_max =  5.385574208
# Average r^2: r2_avg =  0.15951591573
# min r^2: r2_min =  -4.50849383918
# max r^2: r2_max =  0.82570544626
# (train) Average RMSE: RMSE_avg =  3.06219786577
# (train) min RMSE: RMSE_min =  1.12081570773
# (train) max RMSE: RMSE_max =  4.86303474978
# (train) Average r^2: r2_avg =  0.76649843934
# (train) min r^2: r2_min =  0.572573136081
# (train) max r^2: r2_max =  0.854845286631

# %% [markdown]
# <b> PART 4 - some tests on OLS for graphs

# %%
# try OLS on sample 4 - D = 1 sec
OLS(S_X[7], S_y[7], 1, 1)
# Out:
# Coefficients:
#  0.00394840539072
# Mean squared error: 0.39
# r^2: 0.50
# (training) Mean squared error: 0.37
# (training) r^2: 0.59
# (0.0039484053907179878,
#  0.38847070823026447,
#  0.50361209051284805,
#  0.36568771336155648,
#  0.5931477584054492)

# %%
# try OLS on sample 4 - D = 10 sec
OLS(S_X_10[11], S_y_10[11], 10, 1)
# Out:
# Coefficients:
#  0.00643342968823
# Mean squared error: 4.40
# r^2: 0.81
# (training) Mean squared error: 3.90
# (training) r^2: 0.85
# (0.0064334296882339777,
#  4.4032770696631944,
#  0.80644909155069433,
#  3.8962591460541307,
#  0.85121273259202279)

# %% [markdown]
# <b> PART 9 - polynomial regression

# %%
# this function performs polynomial OLS on X,y with degree deg
# takes also as a parameter D (time diff), and to_plot (if we desire plots on the OLS)
def OLS_poly(X,y,deg,D,to_plot):
    
    # 1- augment X to deg
    X_poly = np.zeros((X.shape[0],deg+1))
    for i in range(len(X)):
        for j in range(deg+1):
            X_poly[i,j] = X[i]**j
    
    # 2- poly-OLS
    from sklearn import datasets, linear_model
    from sklearn.metrics import mean_squared_error, r2_score
    from sklearn.model_selection import KFold
    coefs = []
    rmses = []
    r2s = []
    rmses_train = []
    r2s_train = []
    kf = KFold(n_splits=4, random_state=None, shuffle=True)
    kf.get_n_splits(X_poly)
    for train_index, test_index in kf.split(X_poly):
        X_train, X_test, X_test_plot = X_poly[train_index], X_poly[test_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        regr = linear_model.LinearRegression()
        regr.fit(X_train, y_train)
        y_pred = regr.predict(X_test)
        coefs.append(regr.coef_)
        rmses.append(mean_squared_error(y_test, y_pred))
        r2s.append(r2_score(y_test, y_pred))
        y_pred_2 = regr.predict(X_train)
        rmses_train.append(mean_squared_error(y_train, y_pred_2))
        r2s_train.append(r2_score(y_train, y_pred_2))
    coefs = np.array(coefs)
    rmses = np.array(rmses)
    r2s = np.array(r2s)
    rmses_train = np.array(rmses_train)
    r2s_train = np.array(r2s_train)
        
    print('Coefficients: \n', np.mean(coefs))
    print("Mean squared error: %.2f"
              % np.mean(rmses))
    print('r^2: %.2f' % np.mean(r2s))
    print("(training) Mean squared error: %.2f"
              % np.mean(rmses_train))
    print('(training) r^2: %.2f' % np.mean(r2s_train))
    
    if(to_plot == 1):
        # 2- qq-plot of y_test - y_pred against normal distribution
        import pylab 
        import scipy.stats as stats
        measurements = y_test[:,0] - y_pred[:,0]
        stats.probplot(measurements, dist="norm", plot=pylab)
        pylab.title('Poly - qq-plot against normal (' + str(D) + ' sec)')
        pylab.show()

        # 3- qq-plot of y_test - y_pred against uniform distribution
        measurements = y_test[:,0] - y_pred[:,0]
        stats.probplot(measurements, dist="uniform", plot=pylab)
        pylab.title('Poly - qq-plot against uniform (' + str(D) + ' sec)')
        pylab.show()

        # 4- post-OLS_poly plot
        s = [5 for n in range(len(X))]
        X_plot = [x for x,_ in sorted(zip(X_test_plot,y_pred))]
        y_plot = [y for _,y in sorted(zip(X_test_plot,y_pred))]
        title = 'Polynomial OLS - order flow imbalance VS price change (' + str(D) + ' sec)'
        plt.figure()
        plt.scatter(X,y,s=s)
        plt.plot(X_plot, y_plot, color='red')
        plt.xlabel(r'$OFI(t,t+\Delta)$', fontsize=10)
        plt.ylabel(r'$\frac{S(t+\Delta)-S(t)}{\delta}$', fontsize=10)
        plt.axhline(0, linewidth = 0.5, color='grey')
        plt.axvline(0, linewidth = 0.5, color='grey')
        plt.xlim((-500,500))
        plt.ylim((-4,4))
        plt.title(title)
        plt.show()
        
    return np.mean(coefs),np.mean(rmses),np.mean(r2s), np.mean(rmses_train),np.mean(r2s_train)

# %% [markdown]
# <b> PART 10 - testing some polynomial regression

# %%
# try poly OLS of degree 4 - D = 1 sec
OLS_poly(S_X[8], S_y[8],4,1,1)
# Out:
# Coefficients:
#  0.000613759263813
# Mean squared error: 0.63
# r^2: 0.59
# (training) Mean squared error: 0.54
# (training) r^2: 0.64
# (0.00061375926381278983,
#  0.63240406371599034,
#  0.58807164583201998,
#  0.53699262142326343,
#  0.64431957792867323)

# %%
# try poly OLS of degree 4 - D = 10 sec
OLS_poly(S_X_10[12], S_y_10[12],4,10,1)
# Out:
# Coefficients:
#  0.000702500018396
# Mean squared error: 5.24
# r^2: 0.73
# (training) Mean squared error: 4.38
# (training) r^2: 0.80
# (0.00070250001839606223,
#  5.2374787187277789,
#  0.72988685915296658,
#  4.3819849953001917,
#  0.79989666405501714)

# %%
# try poly OLS of degree 9 - D = 1 sec
OLS_poly(S_X[8], S_y[8],9,1,1)
# Out:
# Coefficients:
#  6.29908116413e-15
# Mean squared error: 194.24
# r^2: -157.20
# (training) Mean squared error: 0.66
# (training) r^2: 0.57
# (6.2990811641298481e-15,
#  194.24273664149797,
#  -157.20070553677877,
#  0.65837242805692286,
#  0.56595069907313134)

# %%
# try poly OLS of degree 9 - D = 10 sec
OLS_poly(S_X_10[12], S_y_10[12],9,10,1)
# Out:
# Coefficients:
#  2.1116232467e-15
# Mean squared error: 6.06
# r^2: 0.70
# (training) Mean squared error: 4.28
# (training) r^2: 0.81
# (2.1116232467030627e-15,
#  6.0581515138367203,
#  0.70437119143150428,
#  4.2756900310222479,
#  0.80604004862216916)

# %% [markdown]
# <b> PART 11 - poly OLS on ALL the samples, get the best degree

# %%
# here we get the average OLS info accross all the samples - D = 1 sec
degs = [1,2,3,4,5,6,7]
rmses = []
r2s = []
rmses_train = []
r2s_train = []
for deg in degs:
    sample = 0
    c_avg = 0
    rmse_avg = 0
    r2_avg = 0
    rmse_train_avg = 0
    r2_train_avg = 0
    while(sample < S_X.size):
        c,rmse,r2,rmse_train,r2_train = OLS_poly(S_X[sample],S_y[sample],deg,1,0)
        c_avg = c_avg + c
        rmse_avg = rmse_avg + rmse
        r2_avg = r2_avg + r2
        rmse_train_avg = rmse_train_avg + rmse_train
        r2_train_avg = r2_train_avg + r2_train
        sample = sample + 1
    c_avg = c_avg / sample
    rmse_avg = rmse_avg / sample
    r2_avg = r2_avg / sample
    rmse_train_avg = rmse_train_avg / sample
    r2_train_avg = r2_train_avg / sample
    rmses.append(rmse_avg)
    r2s.append(r2_avg)
    rmses_train.append(rmse_train_avg)
    r2s_train.append(r2_train_avg)

title = 'Train - change of RMSE with d (' + str(1) + ' sec)'
plt.figure()
lines = plt.plot(degs, rmses_train)
plt.setp(lines, 'color', 'b', 'linewidth', 1.0)
plt.xlabel('d', fontsize=10)
plt.ylabel('RMSE', fontsize=10)
plt.title(title)
plt.show()

title = 'Train - change of ' + r'$r^2$'+ ' with d (' + str(1) + ' sec)'
plt.figure()
lines = plt.plot(degs, r2s_train)
plt.setp(lines, 'color', 'g', 'linewidth', 1.0)
plt.xlabel('d', fontsize=10)
plt.ylabel(r'$r^2$', fontsize=10)
plt.title(title)
plt.show()

title = 'Test - change of RMSE with d (' + str(1) + ' sec)'
plt.figure()
lines = plt.plot(degs, rmses)
plt.setp(lines, 'color', 'b', 'linewidth', 1.0)
plt.xlabel('d', fontsize=10)
plt.ylabel('RMSE', fontsize=10)
plt.title(title)
plt.show()

title = 'Test - change of ' + r'$r^2$'+ ' with d (' + str(1) + ' sec)'
plt.figure()
lines = plt.plot(degs, r2s)
plt.setp(lines, 'color', 'g', 'linewidth', 1.0)
plt.xlabel('d', fontsize=10)
plt.ylabel(r'$r^2$', fontsize=10)
plt.title(title)
plt.show()
# Out:
# Coefficients:
#  0.00156935324146
# Mean squared error: 0.36
# r^2: 0.25
# (training) Mean squared error: 0.35
# (training) r^2: 0.38
# Coefficients:
#  0.0017895317
# Mean squared error: 0.41
# r^2: 0.49
# (training) Mean squared error: 0.39
# (training) r^2: 0.51
# Coefficients:
#  0.00197950815954
# Mean squared error: 0.76
# r^2: 0.47
# (training) Mean squared error: 0.70
# (training) r^2: 0.54
# Coefficients:
#  0.00255596892005
# Mean squared error: 0.60
# r^2: 0.64
# (training) Mean squared error: 0.58
# (training) r^2: 0.66
# Coefficients:
#  0.00195438838059
# Mean squared error: 0.38
# r^2: 0.40
# (training) Mean squared error: 0.36
# (training) r^2: 0.52
# Coefficients:
#  0.00252454527204
# Mean squared error: 0.53
# r^2: 0.58
# (training) Mean squared error: 0.51
# (training) r^2: 0.66
# Coefficients:
#  0.00251558149614
# Mean squared error: 0.55
# r^2: 0.51
# (training) Mean squared error: 0.51
# (training) r^2: 0.61
# Coefficients:
#  0.00197681511402
# Mean squared error: 0.39
# r^2: 0.53
# (training) Mean squared error: 0.37
# (training) r^2: 0.59
# Coefficients:
#  0.00207284449641
# Mean squared error: 0.64
# r^2: 0.57
# (training) Mean squared error: 0.63
# (training) r^2: 0.58
# Coefficients:
#  0.00240563311481
# Mean squared error: 0.68
# r^2: 0.60
# (training) Mean squared error: 0.63
# (training) r^2: 0.67
# Coefficients:
#  0.00194768545576
# Mean squared error: 0.53
# r^2: 0.46
# (training) Mean squared error: 0.48
# (training) r^2: 0.57
# Coefficients:
#  0.00254718077448
# Mean squared error: 0.71
# r^2: 0.60
# (training) Mean squared error: 0.67
# (training) r^2: 0.68
# Coefficients:
#  0.00185005416861
# Mean squared error: 1.12
# r^2: 0.52
# (training) Mean squared error: 1.11
# (training) r^2: 0.53
# Coefficients:
#  0.0010557187137
# Mean squared error: 0.36
# r^2: 0.35
# (training) Mean squared error: 0.35
# (training) r^2: 0.38
# Coefficients:
#  0.00119108096537
# Mean squared error: 0.39
# r^2: 0.47
# (training) Mean squared error: 0.35
# (training) r^2: 0.55
# Coefficients:
#  0.00131579911284
# Mean squared error: 0.77
# r^2: 0.50
# (training) Mean squared error: 0.70
# (training) r^2: 0.54
# Coefficients:
#  0.00163960463604
# Mean squared error: 0.66
# r^2: 0.51
# (training) Mean squared error: 0.57
# (training) r^2: 0.67
# Coefficients:
#  0.00130808154833
# Mean squared error: 0.40
# r^2: 0.44
# (training) Mean squared error: 0.35
# (training) r^2: 0.53
# Coefficients:
#  0.00159888744107
# Mean squared error: 0.54
# r^2: 0.60
# (training) Mean squared error: 0.49
# (training) r^2: 0.67
# Coefficients:
#  0.00160694176097
# Mean squared error: 0.75
# r^2: 0.32
# (training) Mean squared error: 0.46
# (training) r^2: 0.63
# Coefficients:
#  0.00128156138873
# Mean squared error: 0.43
# r^2: 0.52
# (training) Mean squared error: 0.35
# (training) r^2: 0.61
# Coefficients:
#  0.00139573862446
# Mean squared error: 0.68
# r^2: 0.55
# (training) Mean squared error: 0.61
# (training) r^2: 0.60
# Coefficients:
#  0.00158739481995
# Mean squared error: 0.64
# r^2: 0.65
# (training) Mean squared error: 0.61
# (training) r^2: 0.68
# Coefficients:
#  0.00116523822322
# Mean squared error: 0.85
# r^2: 0.11
# (training) Mean squared error: 0.43
# (training) r^2: 0.62
# Coefficients:
#  0.00167821417169
# Mean squared error: 0.67
# r^2: 0.68
# (training) Mean squared error: 0.65
# (training) r^2: 0.69
# Coefficients:
#  0.00121143989519
# Mean squared error: 1.19
# r^2: 0.46
# (training) Mean squared error: 1.08
# (training) r^2: 0.54
# Coefficients:
#  0.000552655531709
# Mean squared error: 0.53
# r^2: -0.12
# (training) Mean squared error: 0.32
# (training) r^2: 0.42
# Coefficients:
#  0.000652819597191
# Mean squared error: 0.39
# r^2: 0.47
# (training) Mean squared error: 0.33
# (training) r^2: 0.57
# Coefficients:
#  0.000679148557266
# Mean squared error: 0.85
# r^2: 0.44
# (training) Mean squared error: 0.62
# (training) r^2: 0.60
# Coefficients:
#  0.000715840756356
# Mean squared error: 0.42
# r^2: 0.75
# (training) Mean squared error: 0.41
# (training) r^2: 0.76
# Coefficients:
#  0.000688526819315
# Mean squared error: 0.56
# r^2: 0.27
# (training) Mean squared error: 0.30
# (training) r^2: 0.60
# Coefficients:
#  0.000675650629588
# Mean squared error: 0.39
# r^2: 0.75
# (training) Mean squared error: 0.31
# (training) r^2: 0.79
# Coefficients:
#  0.00078689954057
# Mean squared error: 0.48
# r^2: 0.37
# (training) Mean squared error: 0.38
# (training) r^2: 0.70
# Coefficients:
#  0.000770464431055
# Mean squared error: 1.42
# r^2: -0.41
# (training) Mean squared error: 0.34
# (training) r^2: 0.62
# Coefficients:
#  0.000864740127022
# Mean squared error: 0.67
# r^2: 0.56
# (training) Mean squared error: 0.57
# (training) r^2: 0.62
# Coefficients:
#  0.000801080072234
# Mean squared error: 0.63
# r^2: 0.68
# (training) Mean squared error: 0.52
# (training) r^2: 0.73
# Coefficients:
#  0.000510677217992
# Mean squared error: 0.41
# r^2: 0.62
# (training) Mean squared error: 0.36
# (training) r^2: 0.68
# Coefficients:
#  0.000969061778529
# Mean squared error: 0.65
# r^2: 0.68
# (training) Mean squared error: 0.59
# (training) r^2: 0.72
# Coefficients:
#  0.000861102060167
# Mean squared error: 1.21
# r^2: 0.47
# (training) Mean squared error: 1.08
# (training) r^2: 0.54
# Coefficients:
#  0.000278537926571
# Mean squared error: 0.41
# r^2: 0.17
# (training) Mean squared error: 0.26
# (training) r^2: 0.53
# Coefficients:
#  0.00049163878472
# Mean squared error: 0.79
# r^2: -0.02
# (training) Mean squared error: 0.31
# (training) r^2: 0.60
# Coefficients:
#  0.000579479894927
# Mean squared error: 0.89
# r^2: 0.47
# (training) Mean squared error: 0.63
# (training) r^2: 0.60
# Coefficients:
#  0.000556862818177
# Mean squared error: 0.53
# r^2: 0.68
# (training) Mean squared error: 0.40
# (training) r^2: 0.77
# Coefficients:
#  0.000469075644052
# Mean squared error: 2.72
# r^2: -1.84
# (training) Mean squared error: 0.28
# (training) r^2: 0.63
# Coefficients:
#  0.000522652105176
# Mean squared error: 0.52
# r^2: 0.59
# (training) Mean squared error: 0.32
# (training) r^2: 0.78
# Coefficients:
#  0.000530442088977
# Mean squared error: 1.47
# r^2: 0.04
# (training) Mean squared error: 0.35
# (training) r^2: 0.73
# Coefficients:
#  0.000594132595222
# Mean squared error: 1.87
# r^2: -0.39
# (training) Mean squared error: 0.34
# (training) r^2: 0.62
# Coefficients:
#  0.000599360092959
# Mean squared error: 0.66
# r^2: 0.57
# (training) Mean squared error: 0.53
# (training) r^2: 0.65
# Coefficients:
#  0.000645084059786
# Mean squared error: 0.76
# r^2: 0.38
# (training) Mean squared error: 0.49
# (training) r^2: 0.73
# Coefficients:
#  0.000429746075987
# Mean squared error: 0.53
# r^2: 0.49
# (training) Mean squared error: 0.33
# (training) r^2: 0.71
# Coefficients:
#  0.000766402252891
# Mean squared error: 0.70
# r^2: 0.66
# (training) Mean squared error: 0.59
# (training) r^2: 0.72
# Coefficients:
#  0.000663780762451
# Mean squared error: 1.22
# r^2: 0.48
# (training) Mean squared error: 1.04
# (training) r^2: 0.56
# Coefficients:
#  6.15926647508e-05
# Mean squared error: 0.28
# r^2: 0.46
# (training) Mean squared error: 0.24
# (training) r^2: 0.57
# Coefficients:
#  0.000232389347085
# Mean squared error: 0.36
# r^2: 0.48
# (training) Mean squared error: 0.28
# (training) r^2: 0.65
# Coefficients:
#  0.000277389917865
# Mean squared error: 1.74
# r^2: 0.04
# (training) Mean squared error: 0.60
# (training) r^2: 0.61
# Coefficients:
#  0.000328827350857
# Mean squared error: 0.68
# r^2: 0.62
# (training) Mean squared error: 0.37
# (training) r^2: 0.78
# Coefficients:
#  0.000133267681189
# Mean squared error: 2.23
# r^2: -1.45
# (training) Mean squared error: 0.23
# (training) r^2: 0.68
# Coefficients:
#  0.000358342979198
# Mean squared error: 0.50
# r^2: 0.63
# (training) Mean squared error: 0.30
# (training) r^2: 0.79
# Coefficients:
#  0.000318569789449
# Mean squared error: 91.77
# r^2: -29.38
# (training) Mean squared error: 0.34
# (training) r^2: 0.74
# Coefficients:
#  0.000410747869004
# Mean squared error: 14.58
# r^2: -12.69
# (training) Mean squared error: 0.33
# (training) r^2: 0.64
# Coefficients:
#  0.000466768638983
# Mean squared error: 0.74
# r^2: 0.51
# (training) Mean squared error: 0.53
# (training) r^2: 0.65
# Coefficients:
#  0.00045391784278
# Mean squared error: 0.72
# r^2: 0.51
# (training) Mean squared error: 0.49
# (training) r^2: 0.74
# Coefficients:
#  0.000271009356025
# Mean squared error: 1.05
# r^2: 0.25
# (training) Mean squared error: 0.32
# (training) r^2: 0.72
# Coefficients:
#  0.000322465528097
# Mean squared error: 0.56
# r^2: 0.66
# (training) Mean squared error: 0.44
# (training) r^2: 0.79
# Coefficients:
#  0.00030181771669
# Mean squared error: 1.11
# r^2: 0.52
# (training) Mean squared error: 0.93
# (training) r^2: 0.60
# Coefficients:
#  5.77190936218e-05
# Mean squared error: 0.39
# r^2: 0.11
# (training) Mean squared error: 0.23
# (training) r^2: 0.58
# Coefficients:
#  0.000197129814044
# Mean squared error: 0.44
# r^2: 0.40
# (training) Mean squared error: 0.25
# (training) r^2: 0.67
# Coefficients:
#  0.000232902361804
# Mean squared error: 1.14
# r^2: 0.25
# (training) Mean squared error: 0.60
# (training) r^2: 0.62
# Coefficients:
#  0.000258450220213
# Mean squared error: 4.68
# r^2: -0.63
# (training) Mean squared error: 0.38
# (training) r^2: 0.77
# Coefficients:
#  0.000111955864009
# Mean squared error: 1.43
# r^2: -0.56
# (training) Mean squared error: 0.23
# (training) r^2: 0.69
# Coefficients:
#  0.000254635675728
# Mean squared error: 0.39
# r^2: 0.71
# (training) Mean squared error: 0.30
# (training) r^2: 0.80
# Coefficients:
#  2.23646837682e-05
# Mean squared error: 25.54
# r^2: -9.46
# (training) Mean squared error: 0.22
# (training) r^2: 0.83
# Coefficients:
#  0.000246780406788
# Mean squared error: 0.53
# r^2: 0.40
# (training) Mean squared error: 0.30
# (training) r^2: 0.67
# Coefficients:
#  0.000251223918781
# Mean squared error: 7.78
# r^2: -3.07
# (training) Mean squared error: 0.53
# (training) r^2: 0.65
# Coefficients:
#  0.000154513524509
# Mean squared error: 1.05
# r^2: 0.41
# (training) Mean squared error: 0.51
# (training) r^2: 0.73
# Coefficients:
#  0.00026124269292
# Mean squared error: 0.94
# r^2: 0.35
# (training) Mean squared error: 0.33
# (training) r^2: 0.70
# Coefficients:
#  1.24081003869e-07
# Mean squared error: 2.95
# r^2: -0.54
# (training) Mean squared error: 0.48
# (training) r^2: 0.77
# Coefficients:
#  0.000121489295201
# Mean squared error: 1.06
# r^2: 0.54
# (training) Mean squared error: 0.97
# (training) r^2: 0.59
# Coefficients:
#  -2.07789905793e-07
# Mean squared error: 1.00
# r^2: -0.52
# (training) Mean squared error: 0.23
# (training) r^2: 0.59
# Coefficients:
#  2.35800987525e-09
# Mean squared error: 0.41
# r^2: 0.46
# (training) Mean squared error: 0.28
# (training) r^2: 0.64
# Coefficients:
#  2.13614805743e-09
# Mean squared error: 3.82
# r^2: -1.02
# (training) Mean squared error: 0.59
# (training) r^2: 0.62
# Coefficients:
#  3.24699384287e-09
# Mean squared error: 12.53
# r^2: -5.80
# (training) Mean squared error: 0.39
# (training) r^2: 0.78
# Coefficients:
#  -9.49295622773e-08
# Mean squared error: 6.44
# r^2: -7.46
# (training) Mean squared error: 0.23
# (training) r^2: 0.69
# Coefficients:
#  3.20492212599e-09
# Mean squared error: 1.11
# r^2: 0.34
# (training) Mean squared error: 0.32
# (training) r^2: 0.78
# Coefficients:
#  4.27888559296e-09
# Mean squared error: 78.28
# r^2: -34.08
# (training) Mean squared error: 0.23
# (training) r^2: 0.82
# Coefficients:
#  -1.80204328414e-07
# Mean squared error: 2371.01
# r^2: -1505.24
# (training) Mean squared error: 0.30
# (training) r^2: 0.67
# Coefficients:
#  3.39282690494e-09
# Mean squared error: 4.86
# r^2: -1.99
# (training) Mean squared error: 0.49
# (training) r^2: 0.67
# Coefficients:
#  2.52217310975e-09
# Mean squared error: 0.81
# r^2: 0.57
# (training) Mean squared error: 0.49
# (training) r^2: 0.74
# Coefficients:
#  2.77087954177e-09
# Mean squared error: 3.63
# r^2: -1.87
# (training) Mean squared error: 0.28
# (training) r^2: 0.75
# Coefficients:
#  2.81450799738e-09
# Mean squared error: 2.65
# r^2: -0.00
# (training) Mean squared error: 0.43
# (training) r^2: 0.80
# Coefficients:
#  1.97918045087e-09
# Mean squared error: 1.10
# r^2: 0.53
# (training) Mean squared error: 0.95
# (training) r^2: 0.59

# %%
# here we get the average OLS info accross all the samples - D = 10 sec
degs = [1,2,3,4,5,6,7]
rmses = []
r2s = []
rmses_train = []
r2s_train = []
for deg in degs:
    sample = 0
    c_avg = 0
    rmse_avg = 0
    r2_avg = 0
    rmse_train_avg = 0
    r2_train_avg = 0
    while(sample < S_X_10.size):
        c,rmse,r2,rmse_train,r2_train = OLS_poly(S_X_10[sample],S_y_10[sample],deg,10,0)
        c_avg = c_avg + c
        rmse_avg = rmse_avg + rmse
        r2_avg = r2_avg + r2
        rmse_train_avg = rmse_train_avg + rmse_train
        r2_train_avg = r2_train_avg + r2_train
        sample = sample + 1
    c_avg = c_avg / sample
    rmse_avg = rmse_avg / sample
    r2_avg = r2_avg / sample
    rmse_train_avg = rmse_train_avg / sample
    r2_train_avg = r2_train_avg / sample
    rmses.append(rmse_avg)
    r2s.append(r2_avg)
    rmses_train.append(rmse_train_avg)
    r2s_train.append(r2_train_avg)

title = 'Train - change of RMSE with d (' + str(10) + ' sec)'
plt.figure()
lines = plt.plot(degs, rmses_train)
plt.setp(lines, 'color', 'b', 'linewidth', 1.0)
plt.xlabel('d', fontsize=10)
plt.ylabel('RMSE', fontsize=10)
plt.title(title)
plt.show()

title = 'Train - change of ' + r'$r^2$'+ ' with d (' + str(10) + ' sec)'
plt.figure()
lines = plt.plot(degs, r2s_train)
plt.setp(lines, 'color', 'g', 'linewidth', 1.0)
plt.xlabel('d', fontsize=10)
plt.ylabel(r'$r^2$', fontsize=10)
plt.title(title)
plt.show()

title = 'Test - change of RMSE with d (' + str(10) + ' sec)'
plt.figure()
lines = plt.plot(degs, rmses)
plt.setp(lines, 'color', 'b', 'linewidth', 1.0)
plt.xlabel('d', fontsize=10)
plt.ylabel('RMSE', fontsize=10)
plt.title(title)
plt.show()

title = 'Test - change of ' + r'$r^2$'+ ' with d (' + str(10) + ' sec)'
plt.figure()
lines = plt.plot(degs, r2s)
plt.setp(lines, 'color', 'g', 'linewidth', 1.0)
plt.xlabel('d', fontsize=10)
plt.ylabel(r'$r^2$', fontsize=10)
plt.title(title)
plt.show()
# Out:
# Coefficients:
#  0.00287910859728
# Mean squared error: 1.69
# r^2: 0.01
# (training) Mean squared error: 1.37
# (training) r^2: 0.82
# Coefficients:
#  0.0029745408354
# Mean squared error: 5.52
# r^2: -0.75
# (training) Mean squared error: 4.00
# (training) r^2: 0.65
# Coefficients:
#  0.00256915867809
# Mean squared error: 4.61
# r^2: 0.64
# (training) Mean squared error: 3.57
# (training) r^2: 0.74
# Coefficients:
#  0.00223304849489
# Mean squared error: 4.20
# r^2: 0.45
# (training) Mean squared error: 3.46
# (training) r^2: 0.59
# Coefficients:
#  0.00231098238634
# Mean squared error: 3.71
# r^2: 0.32
# (training) Mean squared error: 2.71
# (training) r^2: 0.66
# Coefficients:
#  0.00319216575411
# Mean squared error: 3.33
# r^2: 0.68
# (training) Mean squared error: 2.57
# (training) r^2: 0.85
# Coefficients:
#  0.00289311007843
# Mean squared error: 3.39
# r^2: 0.63
# (training) Mean squared error: 2.73
# (training) r^2: 0.75
# Coefficients:
#  0.00240813479614
# Mean squared error: 1.59
# r^2: 0.65
# (training) Mean squared error: 1.15
# (training) r^2: 0.83
# Coefficients:
#  0.00283061504765
# Mean squared error: 4.80
# r^2: 0.72
# (training) Mean squared error: 4.39
# (training) r^2: 0.75
# Coefficients:
#  0.00350173247408
# Mean squared error: 3.25
# r^2: 0.79
# (training) Mean squared error: 2.99
# (training) r^2: 0.85
# Coefficients:
#  0.00285985543829
# Mean squared error: 2.52
# r^2: 0.76
# (training) Mean squared error: 2.12
# (training) r^2: 0.83
# Coefficients:
#  0.00321334899752
# Mean squared error: 4.51
# r^2: 0.77
# (training) Mean squared error: 3.89
# (training) r^2: 0.85
# Coefficients:
#  0.00259834859824
# Mean squared error: 5.10
# r^2: 0.76
# (training) Mean squared error: 4.85
# (training) r^2: 0.78
# Coefficients:
#  0.00134379399882
# Mean squared error: 2.67
# r^2: 0.52
# (training) Mean squared error: 1.02
# (training) r^2: 0.87
# Coefficients:
#  0.00151747153339
# Mean squared error: 13.85
# r^2: -1.01
# (training) Mean squared error: 3.07
# (training) r^2: 0.74
# Coefficients:
#  0.00171291893225
# Mean squared error: 5.19
# r^2: 0.55
# (training) Mean squared error: 3.37
# (training) r^2: 0.76
# Coefficients:
#  0.00141873002451
# Mean squared error: 4.13
# r^2: 0.29
# (training) Mean squared error: 3.45
# (training) r^2: 0.57
# Coefficients:
#  0.00146974306943
# Mean squared error: 4.98
# r^2: -0.07
# (training) Mean squared error: 2.59
# (training) r^2: 0.68
# Coefficients:
#  0.00211729979689
# Mean squared error: 2.94
# r^2: 0.68
# (training) Mean squared error: 2.61
# (training) r^2: 0.85
# Coefficients:
#  0.00192545099349
# Mean squared error: 3.39
# r^2: 0.70
# (training) Mean squared error: 2.74
# (training) r^2: 0.76
# Coefficients:
#  0.00160263004583
# Mean squared error: 1.45
# r^2: 0.75
# (training) Mean squared error: 1.15
# (training) r^2: 0.83
# Coefficients:
#  0.00184284747164
# Mean squared error: 5.06
# r^2: 0.69
# (training) Mean squared error: 4.32
# (training) r^2: 0.76
# Coefficients:
#  0.00230304045855
# Mean squared error: 4.01
# r^2: 0.76
# (training) Mean squared error: 2.83
# (training) r^2: 0.86
# Coefficients:
#  0.00187191217505
# Mean squared error: 2.10
# r^2: 0.81
# (training) Mean squared error: 1.91
# (training) r^2: 0.85
# Coefficients:
#  0.00214259773139
# Mean squared error: 4.85
# r^2: 0.79
# (training) Mean squared error: 3.81
# (training) r^2: 0.85
# Coefficients:
#  0.00172447287039
# Mean squared error: 5.50
# r^2: 0.74
# (training) Mean squared error: 4.78
# (training) r^2: 0.78
# Coefficients:
#  0.00111984718444
# Mean squared error: 3.42
# r^2: -0.61
# (training) Mean squared error: 0.75
# (training) r^2: 0.90
# Coefficients:
#  0.000122101446972
# Mean squared error: 5.15
# r^2: 0.22
# (training) Mean squared error: 1.42
# (training) r^2: 0.86
# Coefficients:
#  0.000850140462219
# Mean squared error: 4.87
# r^2: 0.63
# (training) Mean squared error: 2.91
# (training) r^2: 0.79
# Coefficients:
#  0.00037361628203
# Mean squared error: 4.17
# r^2: -0.11
# (training) Mean squared error: 2.75
# (training) r^2: 0.65
# Coefficients:
#  0.000526835113724
# Mean squared error: 3.93
# r^2: 0.52
# (training) Mean squared error: 2.09
# (training) r^2: 0.76
# Coefficients:
#  0.000966347024381
# Mean squared error: 3.28
# r^2: 0.76
# (training) Mean squared error: 1.83
# (training) r^2: 0.89
# Coefficients:
#  0.000899827224817
# Mean squared error: 2.50
# r^2: 0.77
# (training) Mean squared error: 2.25
# (training) r^2: 0.80
# Coefficients:
#  0.00131267554418
# Mean squared error: 2.79
# r^2: 0.48
# (training) Mean squared error: 1.01
# (training) r^2: 0.85
# Coefficients:
#  0.000634959811529
# Mean squared error: 3.46
# r^2: 0.72
# (training) Mean squared error: 2.96
# (training) r^2: 0.83
# Coefficients:
#  0.00111302312342
# Mean squared error: 2.77
# r^2: 0.86
# (training) Mean squared error: 1.98
# (training) r^2: 0.90
# Coefficients:
#  0.00136778249157
# Mean squared error: 5.06
# r^2: 0.41
# (training) Mean squared error: 1.87
# (training) r^2: 0.86
# Coefficients:
#  0.00100266174634
# Mean squared error: 4.30
# r^2: 0.72
# (training) Mean squared error: 3.12
# (training) r^2: 0.88
# Coefficients:
#  0.000867612223242
# Mean squared error: 5.42
# r^2: 0.72
# (training) Mean squared error: 4.38
# (training) r^2: 0.80
# Coefficients:
#  0.000424130121983
# Mean squared error: 2.38
# r^2: 0.60
# (training) Mean squared error: 0.55
# (training) r^2: 0.93
# Coefficients:
#  2.79540224027e-05
# Mean squared error: 4.42
# r^2: 0.03
# (training) Mean squared error: 1.41
# (training) r^2: 0.87
# Coefficients:
#  0.000684420887677
# Mean squared error: 7.02
# r^2: 0.30
# (training) Mean squared error: 2.78
# (training) r^2: 0.80
# Coefficients:
#  0.000100419309344
# Mean squared error: 4.62
# r^2: -0.17
# (training) Mean squared error: 2.39
# (training) r^2: 0.70
# Coefficients:
#  0.000292369393451
# Mean squared error: 7.60
# r^2: 0.25
# (training) Mean squared error: 1.96
# (training) r^2: 0.77
# Coefficients:
#  0.00073512537644
# Mean squared error: 3.43
# r^2: 0.79
# (training) Mean squared error: 1.81
# (training) r^2: 0.90
# Coefficients:
#  0.000589251592126
# Mean squared error: 4.36
# r^2: -0.04
# (training) Mean squared error: 1.94
# (training) r^2: 0.82
# Coefficients:
#  0.000996880552442
# Mean squared error: 1.85
# r^2: 0.67
# (training) Mean squared error: 1.02
# (training) r^2: 0.85
# Coefficients:
#  0.000604590084671
# Mean squared error: 4.33
# r^2: 0.73
# (training) Mean squared error: 2.86
# (training) r^2: 0.84
# Coefficients:
#  0.000844003734401
# Mean squared error: 7.09
# r^2: 0.69
# (training) Mean squared error: 1.85
# (training) r^2: 0.91
# Coefficients:
#  0.000961915652679
# Mean squared error: 9.57
# r^2: -0.15
# (training) Mean squared error: 1.68
# (training) r^2: 0.86
# Coefficients:
#  0.000789644376072
# Mean squared error: 5.32
# r^2: 0.80
# (training) Mean squared error: 3.10
# (training) r^2: 0.88
# Coefficients:
#  0.000716743454212
# Mean squared error: 5.58
# r^2: 0.74
# (training) Mean squared error: 4.35
# (training) r^2: 0.80
# Coefficients:
#  0.00011371121832
# Mean squared error: 11711.89
# r^2: -737.80
# (training) Mean squared error: 0.47
# (training) r^2: 0.93
# Coefficients:
#  -0.000351411533296
# Mean squared error: 868.59
# r^2: -69.83
# (training) Mean squared error: 1.14
# (training) r^2: 0.89
# Coefficients:
#  0.000471870846942
# Mean squared error: 13.45
# r^2: 0.02
# (training) Mean squared error: 2.76
# (training) r^2: 0.80
# Coefficients:
#  -0.00028609591797
# Mean squared error: 3.23
# r^2: 0.28
# (training) Mean squared error: 2.18
# (training) r^2: 0.72
# Coefficients:
#  0.000449387268935
# Mean squared error: 194.65
# r^2: -20.72
# (training) Mean squared error: 1.92
# (training) r^2: 0.76
# Coefficients:
#  0.000357647879351
# Mean squared error: 4.75
# r^2: 0.38
# (training) Mean squared error: 1.54
# (training) r^2: 0.91
# Coefficients:
#  0.000231719946286
# Mean squared error: 89.05
# r^2: -4.71
# (training) Mean squared error: 1.84
# (training) r^2: 0.83
# Coefficients:
#  0.000471983545608
# Mean squared error: 1.89
# r^2: 0.52
# (training) Mean squared error: 0.81
# (training) r^2: 0.89
# Coefficients:
#  0.000653439970021
# Mean squared error: 4.28
# r^2: 0.71
# (training) Mean squared error: 2.75
# (training) r^2: 0.84
# Coefficients:
#  0.000259827527666
# Mean squared error: 4.97
# r^2: 0.78
# (training) Mean squared error: 1.48
# (training) r^2: 0.93
# Coefficients:
#  0.000375582362956
# Mean squared error: 1579.67
# r^2: -84.85
# (training) Mean squared error: 1.21
# (training) r^2: 0.90
# Coefficients:
#  0.000382342631898
# Mean squared error: 5.08
# r^2: 0.78
# (training) Mean squared error: 2.75
# (training) r^2: 0.90
# Coefficients:
#  0.00032188658021
# Mean squared error: 5.75
# r^2: 0.71
# (training) Mean squared error: 4.16
# (training) r^2: 0.81
# Coefficients:
#  -1.68176574039e-07
# Mean squared error: 1928.17
# r^2: -210.73
# (training) Mean squared error: 0.49
# (training) r^2: 0.94
# Coefficients:
#  -0.000123882084179
# Mean squared error: 43.54
# r^2: -1.50
# (training) Mean squared error: 1.11
# (training) r^2: 0.91
# Coefficients:
#  -7.43050389794e-07
# Mean squared error: 81.10
# r^2: -1.94
# (training) Mean squared error: 3.00
# (training) r^2: 0.80
# Coefficients:
#  -8.19045343305e-05
# Mean squared error: 9.80
# r^2: -0.22
# (training) Mean squared error: 1.87
# (training) r^2: 0.77
# Coefficients:
#  0.000106423582808
# Mean squared error: 333.87
# r^2: -19.64
# (training) Mean squared error: 1.70
# (training) r^2: 0.80
# Coefficients:
#  -5.22039460104e-08
# Mean squared error: 3.71
# r^2: 0.72
# (training) Mean squared error: 1.64
# (training) r^2: 0.90
# Coefficients:
#  3.58127054366e-05
# Mean squared error: 33.71
# r^2: -0.72
# (training) Mean squared error: 1.75
# (training) r^2: 0.83
# Coefficients:
#  0.000120412494453
# Mean squared error: 1.43
# r^2: 0.68
# (training) Mean squared error: 0.68
# (training) r^2: 0.89
# Coefficients:
#  -2.027522402e-07
# Mean squared error: 4.83
# r^2: 0.66
# (training) Mean squared error: 3.24
# (training) r^2: 0.81
# Coefficients:
#  -4.49242743983e-07
# Mean squared error: 135.94
# r^2: -4.42
# (training) Mean squared error: 1.33
# (training) r^2: 0.93
# Coefficients:
#  -1.24037416004e-06
# Mean squared error: 1514.68
# r^2: -114.32
# (training) Mean squared error: 1.12
# (training) r^2: 0.91
# Coefficients:
#  1.37565628425e-07
# Mean squared error: 8.65
# r^2: 0.65
# (training) Mean squared error: 2.70
# (training) r^2: 0.90
# Coefficients:
#  4.04518340268e-07
# Mean squared error: 5.65
# r^2: 0.71
# (training) Mean squared error: 4.22
# (training) r^2: 0.81
# Coefficients:
#  9.47800382192e-09
# Mean squared error: 203016.79
# r^2: -17106.00
# (training) Mean squared error: 0.38
# (training) r^2: 0.95
# Coefficients:
#  -2.23914062335e-10
# Mean squared error: 457599.59
# r^2: -10028.69
# (training) Mean squared error: 1.10
# (training) r^2: 0.83
# Coefficients:
#  1.69200016249e-09
# Mean squared error: 370.37
# r^2: -15.43
# (training) Mean squared error: 2.76
# (training) r^2: 0.81
# Coefficients:
#  4.49471523068e-10
# Mean squared error: 10.54
# r^2: -0.60
# (training) Mean squared error: 1.95
# (training) r^2: 0.73
# Coefficients:
#  1.59562651401e-09
# Mean squared error: 175.33
# r^2: -14.96
# (training) Mean squared error: 1.83
# (training) r^2: 0.78
# Coefficients:
#  2.22104776747e-09
# Mean squared error: 23.12
# r^2: -0.13
# (training) Mean squared error: 1.51
# (training) r^2: 0.91
# Coefficients:
#  2.69957961475e-09
# Mean squared error: 1852.51
# r^2: -129.70
# (training) Mean squared error: 1.72
# (training) r^2: 0.85
# Coefficients:
#  3.13885384188e-09
# Mean squared error: 91.60
# r^2: -12.10
# (training) Mean squared error: 0.79
# (training) r^2: 0.88
# Coefficients:
#  1.4223186375e-09
# Mean squared error: 7.49
# r^2: 0.58
# (training) Mean squared error: 3.18
# (training) r^2: 0.82
# Coefficients:
#  2.56768330088e-09
# Mean squared error: 32.10
# r^2: -0.28
# (training) Mean squared error: 1.16
# (training) r^2: 0.94
# Coefficients:
#  3.20354139137e-09
# Mean squared error: 149127.95
# r^2: -8040.67
# (training) Mean squared error: 1.13
# (training) r^2: 0.91
# Coefficients:
#  2.12862827381e-09
# Mean squared error: 5.32
# r^2: 0.76
# (training) Mean squared error: 2.71
# (training) r^2: 0.90
# Coefficients:
#  1.35190534158e-09
# Mean squared error: 6.02
# r^2: 0.73
# (training) Mean squared error: 4.28
# (training) r^2: 0.81
